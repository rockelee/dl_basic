# %%
import numpy as np

# %%
# data I/O
#data = open('input.txt', 'r').read() # should be simple plain text file
data = "A loop allows information to be passed from one step of the network to the next."
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print 'data has %d characters, %d unique.' % (data_size, vocab_size)
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
    """
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev) #initial hidden state, since we have hs[t-1]
    loss = 0

    # forward pass
    for t in xrange(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        # The mean of ps[t][targets[t],0]:
        # Targets is a list of integers (so targets[t] is an integer which plays index) and ps[t] a column matrix, 
        # so ps[t][targets[t], 0] -> ps[t][targets[t]][0]
        # More generally with x, a numpy matrix with (2,4) shape, x[1, 3] == x[1][3]
        # Unlike lists and tuples, numpy arrays support multidimensional indexing for multidimensional arrays. 
        # That means that it is not necessary to separate each dimension's index into its own set of square brackets.
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)

    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(xrange(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        #print(dWhy.shape, dy.shape, hs[t].shape)
        dby += dy
        
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
    """ 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in xrange(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())  #这里也是随机选的，为什么
        # random.choice is to pick one index from range(vocal_size) with probability stated in p
        # So it's the same with argmax
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
n, p = 0, 0

#np.zeros_like: Return an array of zeros with the same shape and type as a given array
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why) 
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0   #这里固定了句子的长度，应该是一个句子的loss

while n < 20000:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = np.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    # sample from the model now and then
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print '----\n %s \n----' % (txt, )

    # forward seq_length characters through the net and fetch gradient, hprev is previous hidden state
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001   #为什么
    if n % 100 == 0: 
        print 'iter %d, loss: %f' % (n, smooth_loss) # print progress

    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# ----
#   loop allon onetwormation ts innethe network the networpatiof to be pasto the ne ne ne step one a on to ssed fro tne network be passed from ons infob be pallewk one network to the nformased of ohe nfo
# ----
# iter 0, loss: 76.039905
# ----
#  ltf palds inep inftws inep on tne nfonk inepboon on tws infomathe nfon thetwwwrkmabion trkm llowrrn thhe to be netwomathwonmatetwwn th thes tf pas thetithe om inethe nnetwon tne pfo tasailowrmate pafh
# ----
# iter 100, loss: 74.683396
# ----
#   p ork be the nfok the ne nfommalloo tiom of thes or ssaon to the networmethep on the n tne ate pallork tne ned the of ows oneto s ofrtws on tf to to tiinetwos one niows on to tiows on twon to  ilows
# ----
# iter 200, loss: 69.281927
# ----
#   loop iine nekep one saeows lork to tfos alowortwork the obk pfonetfork to the network thepation to to to to the nebe betwows the network the  ofork the netwow ed ofrom onfon thetwlof network toetop o
# ----
# iter 300, loss: 63.694064
# ----
#  the nformation thetws of the network the patiop iows oneto paof to  sed of the nhe nhe network to the nwon the nformform ofe from one ssaof the paiof the network tfd astork of thfork to the nsto bep o
# ----
# iter 400, loss: 58.283368
# ----
#   be netwromatiom one step of bep one step on s ed frk the netop one  abe network the ne networbep one be network the ned fork thetwlof be netwootep of  step llows to network to tito the netop of the n
# ----
# iter 500, loss: 53.296604
# ----
#   loop allows informatformation ts iof the network to the nion the nhepatiohe ofep one step of the network the network the nwormation to to pass on to the network to the nek the nformatd of tne ste pas
# ----
# iter 600, loss: 48.841842
# ----
#  to te passed from one stion to the natne step of the network tf s allows information tomeof to the passed allows information to the natiop to the ptep ork the networhe passaoheto bep one step of to to
# ----
# iter 700, loss: 44.544142
# ----
#   betop ofs onetop onetwllow fon to to to to top of be be on fork the nformaofrom onethetwllof tfrp onetwllork to to thdtwllows on llorp illofrn to the ofrom inetinformformatork be pformformformformfor
# ----
# iter 800, loss: 40.604613
# ----
#   loop allows informassed fromste tiof to be passeiws information to be pfe  aflork to the network to to be passed from of the network to thetwork to the nhep of the nee  aiine network to thetwork to t
# ----
# iter 900, loss: 37.001714
# ----
#  to the passed from one step od ofe passed from oneto the network to the network to thetwork the nors ineto bep of the  te nformation to be passed from one step one step ofm one stion ts dfrom one netw
# ----
# iter 1000, loss: 33.774838
# ----
#  p of the network to the network the network to thoom one step of the from one step of the netwowsed ofe network to the network to the nformation to be passed from one step of the network to the netwow
# ----
# iter 1100, loss: 30.697312
# ----
#   loop allows information to be passed from on to the network to the network to the network to to bep one step of the network to the natfe natwows information to bhep of the network to the netwowbep of
# ----
# iter 1200, loss: 27.888667
# ----
#  to be passed fowr  aseows information to be passed from one step of tne step of the ssed from one stetwork to the network to tne  assed from one stion to bfork to the nwork to the network to the nform
# ----
# iter 1300, loss: 25.332367
# ----
#  p of the network to the network to the network to the network to the network to te be passed from one step ofe fork to bd s ddssallows information to be passed from one step of the nekwor ste be passe
# ----
# iter 1400, loss: 23.007604
# ----
#   loop allows iine ne network to the network to the network to the network to the network to the netwo  ed from one step of the netwowsssed frop the network to the nformation to be pione step of the ne
# ----
# iter 1500, loss: 20.894834
# ----
#  to be paslefrk to the from one step of the network to the network thfork to the network to the nhe network to the network to the network be passed from one step of the network to the network to the ne
# ----
# iter 1600, loss: 18.976156
# ----
#  p of the network to the nek to the network to the network to the network to the netop information to be passed ffork to the network to the network to the network to the network to the network to the n
# ----
# iter 1700, loss: 17.233536
# ----
#   loop allows information to be passed from one step ofrom one step one step of the network to the network to the nformation to be passed from one step of the network to the network to the network to t
# ----
# iter 1800, loss: 15.651287
# ----
#  to be passed from one samlork to the network to the network to the network to the network to the network to the network to te ne network to the network to the norp information to be passed from one st
# ----
# iter 1900, loss: 14.215538
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the netwows information to be passed from one step ifrom one step of the ne
# ----
# iter 2000, loss: 12.912074
# ----
#   loop allows information to be passed from one step ione step of the network to the network to the ne pation to fe passed from one step of the natfe natione step of the network to the network to the n
# ----
# iter 2100, loss: 11.727964
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 2200, loss: 10.653070
# ----
#   paslon the network to the network to the network to the network the nformation to be passed frrmation to be passed from one step of the netwos information to be passed fo pallows information to be pa
# ----
# iter 2300, loss: 9.677519
# ----
#   loop allows allows ion to the network to the network to the network to tne  assed from one step of the network to the network to the network to the network to the network to the network he passed fro
# ----
# iter 2400, loss: 8.792211
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network the nformation to be passed from one s
# ----
# iter 2500, loss: 7.989136
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to tione step of ssed of the network to the network to the network to the network to the netw
# ----
# iter 2600, loss: 7.260480
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 2700, loss: 6.599420
# ----
#  to be passed from one step of the nhe nformation to be passed from one ste passed from one step of the network to the network to the network to the network to the network to the network to the network
# ----
# iter 2800, loss: 5.999985
# ----
#  p of the network to the network to the ne network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network
# ----
# iter 2900, loss: 5.456146
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network the nformation to be passed from one step o
# ----
# iter 3000, loss: 4.962757
# ----
#  to be pariwfrom one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network thfork one
# ----
# iter 3100, loss: 4.515316
# ----
#   passed from one step of the network to the network to the network to the nete step of the network to the network to the network to the network to the noom information to be passed from one step one s
# ----
# iter 3200, loss: 4.109247
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the natne step of the net
# ----
# iter 3300, loss: 3.740742
# ----
#  to be passed from one step of the network to the netwom of the network to the network to the network to the network to the network to the network to the network to the network to the network to the ne
# ----
# iter 3400, loss: 3.406528
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 3500, loss: 3.103216
# ----
#   loop allows on to the nhe network to the network to the network to the network to the neep of the network to the network to the network to the network to the network to the network to the ne network
# ----
# iter 3600, loss: 2.827928
# ----
#  to be passed from one step of thed inhe network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 3700, loss: 2.578153
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 3800, loss: 2.351235
# ----
#   loop allows information to ssed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network twos information t
# ----
# iter 3900, loss: 2.145091
# ----
#  to be passed from one stion to be passed from one step of the network to the network to the network to the network to the network to the network to the network to be passed from one step of the networ
# ----
# iter 4000, loss: 1.957925
# ----
#  p of the network to the network to the network to the network to the network to the network to the ne network to the network to the network to the network to the network to the network to the network
# ----
# iter 4100, loss: 1.787935
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 4200, loss: 1.633566
# ----
#  to bion to be passed from one step of the network to the network to the network to the network to the n the network to the network to the network to the network to the network to the network to the ne
# ----
# iter 4300, loss: 1.493511
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 4400, loss: 1.366285
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the nation to be passed from one step of the network to the network to the network to
# ----
# iter 4500, loss: 1.250704
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 4600, loss: 1.145815
# ----
#  p of the network to the network the nformation to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the netwom of the
# ----
# iter 4700, loss: 1.050479
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 4800, loss: 0.963989
# ----
#  to be passed from one step of the network to the network to the network to the network to the nets the network to the network to the network to the network to the ne network to the network to the netw
# ----
# iter 4900, loss: 0.885297
# ----
#  p of the network to the network to the network to the network to the network to the nhe passed from one step of the network to the network to the network to the network to the network to the network t
# ----
# iter 5000, loss: 0.813719
# ----
#   loop allows information to be passed from one step of the network to the network psed from one step of the network to the networbe be passed from one step of the network to the network to the network
# ----
# iter 5100, loss: 0.748604
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 5200, loss: 0.689457
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network toe step of the ne
# ----
# iter 5300, loss: 0.635596
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 5400, loss: 0.586535
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the norp information to be passed from one step of the network to the network to the network to
# ----
# iter 5500, loss: 0.541911
# ----
#   be as infrom one step of be be network to be network to te network to be networo tep of the network information assed from one step iows inetwork on to  information to ted from one step of the nation
# ----
# iter 5600, loss: 0.531882
# ----
#   loop allows information to be passed from one step of the network to the network pfrom one step of the network to the netwo  information to be passed from one step of the network to the network to be
# ----
# iter 5700, loss: 0.694641
# ----
#  to be passed from the network to the network to the network to the network to the network thhep informatilnformation to be pafe be passed from one step of the network to the nformation to be passed fr
# ----
# iter 5800, loss: 0.659236
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to toepation to be
# ----
# iter 5900, loss: 0.621659
# ----
#   loop allows information to be passed from on the network to the network to the network to the network to the network to the network to the network to the netwow ione step of the network to the networ
# ----
# iter 6000, loss: 0.584398
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 6100, loss: 0.548903
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the netwo  allo
# ----
# iter 6200, loss: 0.515421
# ----
#   loop alorom one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 6300, loss: 0.484147
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the netwow ainformation to be passed from one step of the network to the network
# ----
# iter 6400, loss: 0.455157
# ----
#  p of the network to the network to the network to the network to the network to the network to the networkrom of the network to the network to the network to the network to the network to the network
# ----
# iter 6500, loss: 0.428264
# ----
#   loop allows information to be passed from one step of the network to the network to the ne ne s allows information to be passed from one step of the network to the network to the network to the netwo
# ----
# iter 6600, loss: 0.403421
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 6700, loss: 0.380544
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 6800, loss: 0.359359
# ----
#   loop allows informassed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the netw
# ----
# iter 6900, loss: 0.339788
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to thete from one step of the network to tne  ione st
# ----
# iter 7000, loss: 0.321754
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 7100, loss: 0.305009
# ----
#   loop allows the network to the network to the neepatas ed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the
# ----
# iter 7200, loss: 0.289488
# ----
#  to be passeep one step of the netwows on to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the ne
# ----
# iter 7300, loss: 0.275157
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 7400, loss: 0.261819
# ----
#   loop allows information  ssed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to th
# ----
# iter 7500, loss: 0.249447
# ----
#  to be passed from one step of the network to the network to the netwo assed from one step of the network to the network to the network to the network to the network to the network to the network to th
# ----
# iter 7600, loss: 0.238042
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 7700, loss: 0.227415
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 7800, loss: 0.217542
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the netwoneto be passed from one step of the network to the network to the netwo
# ----
# iter 7900, loss: 0.208434
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 8000, loss: 0.199919
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 8100, loss: 0.191984
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 8200, loss: 0.184655
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 8300, loss: 0.177777
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the netwo  allows information to be passed from one step of the network to the networ
# ----
# iter 8400, loss: 0.171346
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 8500, loss: 0.165395
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to to sssed from one step of the network to the network to the network to the
# ----
# iter 8600, loss: 0.159777
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 8700, loss: 0.154496
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 8800, loss: 0.149608
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 8900, loss: 0.144985
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to tato the nformation to be passed from on
# ----
# iter 9000, loss: 0.140633
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 9100, loss: 0.136600
# ----
#  p of the network to the network to the network to the network to the from one step of the network to the network to the network to the network to the network to the network to the network to the netwo
# ----
# iter 9200, loss: 0.132766
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 9300, loss: 0.129154
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the netwows information to be passe
# ----
# iter 9400, loss: 0.125859
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the neto be pas
# ----
# iter 9500, loss: 0.122697
# ----
#   loop allows information to be passed from one step of the netwows information to be passed from one step of the network to the network to the network to the network to the network to the network to t
# ----
# iter 9600, loss: 0.119687
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 9700, loss: 0.116878
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 9800, loss: 0.114164
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 9900, loss: 0.111522
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 10000, loss: 0.108979
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 10100, loss: 0.106501
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 10200, loss: 0.104108
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 10300, loss: 0.101857
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the oased from one step of the network to the network to the
# ----
# iter 10400, loss: 0.099669
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the nformation to be passed from one step of the networ
# ----
# iter 10500, loss: 0.097562
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 10600, loss: 0.095587
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 10700, loss: 0.093670
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 10800, loss: 0.091823
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 10900, loss: 0.090093
# ----
#  p of the network to the network to the network to the network to be passed from one step of the network to the network to the network to the network to the nfork to the network to the network to the n
# ----
# iter 11000, loss: 0.088408
# ----
#   loop allows information to be passed from one be passed from one step of tne step of the network to the network to the network to the network to the network to the network to the network to the netwo
# ----
# iter 11100, loss: 0.086773
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 11200, loss: 0.085229
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 11300, loss: 0.083717
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 11400, loss: 0.082249
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the networm of the network to the network to the network to the n
# ----
# iter 11500, loss: 0.080870
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to tione step of the network to the network to the network to the network to the network to t
# ----
# iter 11600, loss: 0.079519
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 11700, loss: 0.078200
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 11800, loss: 0.076964
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 11900, loss: 0.075749
# ----
#   loop atwormation to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to th
# ----
# iter 12000, loss: 0.074541
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 12100, loss: 0.073405
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 12200, loss: 0.072294
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 12300, loss: 0.071210
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 12400, loss: 0.070187
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the nhe paslto  aelows information to be passed from one ste
# ----
# iter 12500, loss: 0.069170
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 12600, loss: 0.068173
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 12700, loss: 0.067233
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the netwows information to be passed from one
# ----
# iter 12800, loss: 0.066296
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the netrom one step of the network to th
# ----
# iter 12900, loss: 0.065378
# ----
#  to be passed from one step of the natne step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to th
# ----
# iter 13000, loss: 0.064517
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 13100, loss: 0.063655
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 13200, loss: 0.062806
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 13300, loss: 0.062003
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 13400, loss: 0.061193
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 13500, loss: 0.060434
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 13600, loss: 0.059679
# ----
#  p or be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the
# ----
# iter 13700, loss: 0.058907
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 13800, loss: 0.058141
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 13900, loss: 0.057414
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 14000, loss: 0.056674
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 14100, loss: 0.055937
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 14200, loss: 0.055237
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 14300, loss: 0.054523
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 14400, loss: 0.053816
# ----
#  to be passed from one step of the network to the network the nformation to be passed from one step of the network to the network to the network to the network to the network to the network to the netw
# ----
# iter 14500, loss: 0.053147
# ----
#  p of the network to the network to the network to the network to the netwows information to be passed from one step of the network to the network to the network to the network to the network to the ne
# ----
# iter 14600, loss: 0.052469
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 14700, loss: 0.051800
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 14800, loss: 0.051173
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 14900, loss: 0.050536
# ----
#   loopbe paflon to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to th
# ----
# iter 15000, loss: 0.049985
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to tne step of the network to the netw
# ----
# iter 15100, loss: 0.049404
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network psed ne passed from one step of the network to t
# ----
# iter 15200, loss: 0.048780
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 15300, loss: 0.048146
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to tato
# ----
# iter 15400, loss: 0.047537
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 15500, loss: 0.046916
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 15600, loss: 0.046302
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 15700, loss: 0.045725
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the ned of the network to the network to the network to the network to the
# ----
# iter 15800, loss: 0.045144
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 15900, loss: 0.044576
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 16000, loss: 0.044048
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 16100, loss: 0.043516
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 16200, loss: 0.042997
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 16300, loss: 0.042515
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 16400, loss: 0.042029
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 16500, loss: 0.041555
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the networkm one ste
# ----
# iter 16600, loss: 0.041116
# ----
#  p of the network to the network to the network to the network to the network to the network to the ne passed from one step of the network to the network to the network to the network to the network to
# ----
# iter 16700, loss: 0.040672
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 16800, loss: 0.040238
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 16900, loss: 0.039837
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 17000, loss: 0.039429
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 17100, loss: 0.039031
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the massed from one step of the network to the network to the network to the ned
# ----
# iter 17200, loss: 0.038663
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 17300, loss: 0.038288
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 17400, loss: 0.037921
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 17500, loss: 0.037583
# ----
#  p of the network to the network to the network to the network to the network to the ned or step of the network to the network to the network to the network to the network to the network to the network
# ----
# iter 17600, loss: 0.037236
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 17700, loss: 0.036896
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 17800, loss: 0.036584
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 17900, loss: 0.036262
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 18000, loss: 0.035946
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 18100, loss: 0.035656
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the ne ne pation to be passed from one step o
# ----
# iter 18200, loss: 0.035357
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 18300, loss: 0.035062
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 18400, loss: 0.034792
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 18500, loss: 0.034511
# ----
#   loop allows information to be pathe ofe ated from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to th
# ----
# iter 18600, loss: 0.034235
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 18700, loss: 0.033982
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 18800, loss: 0.033719
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 18900, loss: 0.033459
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 19000, loss: 0.033221
# ----
#  p of the network to the ne network to the network to the networm of to the network to the network to the network to the network to the network to the network to the network to the network to the netwo
# ----
# iter 19100, loss: 0.032973
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 19200, loss: 0.032727
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 19300, loss: 0.032503
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 19400, loss: 0.032267
# ----
#   loop allows information to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the networ
# ----
# iter 19500, loss: 0.032034
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the n
# ----
# iter 19600, loss: 0.031822
# ----
#  p of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to
# ----
# iter 19700, loss: 0.031599
# ----
#   loop allows in to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to t
# ----
# iter 19800, loss: 0.031377
# ----
#  to be passed from one step of the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to the network to tp ll
# ----
# iter 19900, loss: 0.031176

# %%
i = 0
j = 0
data[i + j * ]

# %%
############################################################################################
